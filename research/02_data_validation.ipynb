# %%
import os
os.chdir("../")
# %pwd
# Out:
# 'd:\\Project\\MLOP'

# %%
import logging
import sys

# Setting up logging to show up in the notebook
logging.basicConfig(
    level=logging.INFO,
    format='[%(asctime)s: %(levelname)s: %(module)s: %(message)s]',
    handlers=[
        logging.StreamHandler(sys.stdout)
    ]
)

logger = logging.getLogger("mlProjectLogger")

# %%
from src.mlProject.pipeline.stage_02_data_validation import DataValidationTrainingPipeline
STAGE_NAME = "Data Validation stage"
try:
   logger.info(f">>>>>> stage {STAGE_NAME} started <<<<<<") 
   data_ingestion = DataValidationTrainingPipeline()
   data_ingestion.main()
   logger.info(f">>>>>> stage {STAGE_NAME} completed <<<<<<\n\nx==========x")
except Exception as e:
        logger.exception(e)
        raise e
# Out:
# [2026-04-02 13:52:05,236: INFO: 1977592487: >>>>>> stage Data Validation stage started <<<<<<]
# [2026-04-02 13:52:05,237: INFO: common: yaml file: config\config.yaml loaded successfully]
# [2026-04-02 13:52:05,239: INFO: common: yaml file: config\params.yaml loaded successfully]
# [2026-04-02 13:52:05,241: INFO: common: yaml file: config\schema.yaml loaded successfully]
# [2026-04-02 13:52:05,242: INFO: common: created directory at: artifacts]
# [2026-04-02 13:52:05,242: INFO: common: created directory at: artifacts/data_validation]
# [2026-04-02 13:52:05,260: INFO: 1977592487: >>>>>> stage Data Validation stage completed <<<<<<
#
# x==========x]
