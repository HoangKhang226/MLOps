# %%
import os
os.chdir("../")
# %pwd
# Out:
# 'd:\\Project\\MLOP'

# %%
import logging
import sys

# Setting up logging to show up in the notebook
logging.basicConfig(
    level=logging.INFO,
    format='[%(asctime)s: %(levelname)s: %(module)s: %(message)s]',
    handlers=[
        logging.StreamHandler(sys.stdout)
    ]
)

logger = logging.getLogger("mlProjectLogger")

# %%
from src.mlProject.pipeline.stage_04_model_trainer import ModelTrainerTrainingPipeline
STAGE_NAME = "Model Trainer stage"
try:
   logger.info(f">>>>>> stage {STAGE_NAME} started <<<<<<") 
   model_trainer = ModelTrainerTrainingPipeline()
   model_trainer.main()
   logger.info(f">>>>>> stage {STAGE_NAME} completed <<<<<<\n\nx==========x")
except Exception as e:
        logger.exception(e)
        raise e
# Out:
# [2026-04-02 15:44:00,145: INFO: 3959590922: >>>>>> stage Model Trainer stage started <<<<<<]
# [2026-04-02 15:44:00,148: INFO: common: yaml file: config\config.yaml loaded successfully]
# [2026-04-02 15:44:00,149: INFO: common: yaml file: config\params.yaml loaded successfully]
# [2026-04-02 15:44:00,151: INFO: common: yaml file: config\schema.yaml loaded successfully]
# [2026-04-02 15:44:00,152: INFO: common: created directory at: artifacts]
# [2026-04-02 15:44:00,152: INFO: common: created directory at: artifacts/model_trainer]
# [2026-04-02 15:44:00,181: INFO: model_trainer: Tuning Random Forest...]
# 2026/04/02 15:44:07 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/04/02 15:44:07 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html
# [2026-04-02 15:44:11,186: INFO: model_trainer: Model RandomForest logged with F1: 0.6410564225690276]
# [2026-04-02 15:44:11,194: INFO: model_trainer: Tuning XGBoost...]
# Registered model 'RandomForest' already exists. Creating a new version of this model...
# Created version '2' of model 'RandomForest'.
# d:\Project\MLOP\venv\Lib\site-packages\xgboost\training.py:200: UserWarning: [15:44:14] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# d:\Project\MLOP\venv\Lib\site-packages\xgboost\training.py:200: UserWarning: [15:44:14] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# 2026/04/02 15:44:14 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/04/02 15:44:14 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html
# [2026-04-02 15:44:17,221: INFO: model_trainer: Model XGBoost logged with F1: 0.639412997903564]
# [2026-04-02 15:44:17,226: INFO: model_trainer: Best Model Selected: RandomForest with F1: 0.6410564225690276]
# [2026-04-02 15:44:17,247: INFO: model_trainer: Best model saved to artifacts\model_trainer]
# [2026-04-02 15:44:17,249: INFO: 3959590922: >>>>>> stage Model Trainer stage completed <<<<<<
#
# x==========x]
# Registered model 'XGBoost' already exists. Creating a new version of this model...
# Created version '2' of model 'XGBoost'.
