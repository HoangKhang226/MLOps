# %% [markdown]
# # Data Ingestion Stage

# %%
import os
os.chdir("../")
# %pwd
# Out:
# 'd:\\Project\\MLOP'

# %%
import logging
import sys

# Setting up logging to show up in the notebook
logging.basicConfig(
    level=logging.INFO,
    format='[%(asctime)s: %(levelname)s: %(module)s: %(message)s]',
    handlers=[
        logging.StreamHandler(sys.stdout)
    ]
)

logger = logging.getLogger("mlProjectLogger")

# %%
from src.mlProject.pipeline.stage_01_data_ingestion import DataIngestionTrainingPipeline

STAGE_NAME = "Data Ingestion stage"
try:
   logger.info(f">>>>>> stage {STAGE_NAME} started <<<<<<") 
   data_ingestion = DataIngestionTrainingPipeline()
   data_ingestion.main()
   logger.info(f">>>>>> stage {STAGE_NAME} completed <<<<<<\n\nx==========x")
except Exception as e:
        logger.exception(e)
        raise e
# Out:
# [2026-04-02 13:51:54,503: INFO: 1338452253: >>>>>> stage Data Ingestion stage started <<<<<<]
# [2026-04-02 13:51:54,506: INFO: common: yaml file: config\config.yaml loaded successfully]
# [2026-04-02 13:51:54,507: INFO: common: yaml file: config\params.yaml loaded successfully]
# [2026-04-02 13:51:54,507: INFO: common: yaml file: config\schema.yaml loaded successfully]
# [2026-04-02 13:51:54,510: INFO: common: created directory at: artifacts]
# [2026-04-02 13:51:54,510: INFO: common: created directory at: artifacts/data_ingestion]
# [2026-04-02 13:51:54,511: INFO: data_ingestion: File already exists of size: ~ 23 KB]
# [2026-04-02 13:51:54,521: INFO: 1338452253: >>>>>> stage Data Ingestion stage completed <<<<<<
#
# x==========x]
